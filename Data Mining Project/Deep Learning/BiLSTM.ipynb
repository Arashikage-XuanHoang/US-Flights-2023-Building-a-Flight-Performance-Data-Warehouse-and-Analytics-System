# %%
# === Core Python Utilities ===
import os
import re
import math
import random
import warnings
from datetime import datetime
from itertools import combinations
from collections import Counter
from typing import List, Tuple, Dict, Optional

# === Scientific Computing ===
import numpy as np
import pandas as pd
import scipy
from scipy.stats import skew

# === Visualization ===
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# === Progress & Optimization ===
from tqdm.notebook import tqdm
tqdm.pandas()
import optuna

# %%
# Một số setting cơ bản
import warnings
import pandas as pd
warnings.filterwarnings ('ignore')
pd.set_option ('display.width', None)
pd.set_option ('display.max_rows', 100)
pd.set_option ('display.max_columns', 50)

# %% [markdown]
# # 1. Data

# %%
file_path = '/Users/kittnguyen/Documents/us-flight-project/data/silver_data/'
X_train = np.load(f"/kaggle/input/cleandata/X_train.npy", allow_pickle=True)
y_train = np.load(f"/kaggle/input/cleandata/y_train.npy", allow_pickle=True)
X_dev = np.load(f"/kaggle/input/cleandata/X_dev.npy", allow_pickle=True)
y_dev = np.load(f"/kaggle/input/cleandata/y_dev.npy", allow_pickle=True)
X_test = np.load(f"/kaggle/input/cleandata/X_test.npy", allow_pickle=True)
y_test = np.load(f"/kaggle/input/cleandata/y_test.npy", allow_pickle=True)

# %%
timesteps = 1
X_train = X_train.reshape(X_train.shape[0], timesteps, X_train.shape[1])
X_dev = X_dev.reshape(X_dev.shape[0], timesteps, X_dev.shape[1])
X_test = X_test.reshape(X_test.shape[0], timesteps, X_test.shape[1])

# %% [markdown]
# # 2. BiLSTM Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class BiLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_dim1=128, hidden_dim2=64, fc_dim=16, dropout_rates=(0.4, 0.4, 0.3)):
        super(BiLSTMModel, self).__init__()
        # BiLSTM đầu tiên (2 chiều)
        self.bilstm1 = nn.LSTM(input_size=input_size, hidden_size=hidden_dim1, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(dropout_rates[0])
        
        # BiLSTM thứ 2 (2 chiều)
        # Lưu ý: input_size của LSTM thứ 2 phải là hidden_dim1 * 2 vì bidirectional
        self.bilstm2 = nn.LSTM(input_size=hidden_dim1*2, hidden_size=hidden_dim2, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(dropout_rates[1])
        
        # Fully connected layers
        # input cho fc phải là hidden_dim2 * 2 do BiLSTM thứ 2 2 chiều
        self.fc1 = nn.Linear(hidden_dim2 * 2, fc_dim)
        self.dropout3 = nn.Dropout(dropout_rates[2])
        
        self.out = nn.Linear(fc_dim, 1)
    
    def forward(self, x):
        # x: (batch_size, seq_len, input_size)
        lstm_out1, _ = self.bilstm1(x)  # (batch_size, seq_len, hidden_dim1 * 2)
        lstm_out1 = self.dropout1(lstm_out1)
        
        lstm_out2, _ = self.bilstm2(lstm_out1)  # (batch_size, seq_len, hidden_dim2 * 2)
        lstm_out2 = self.dropout2(lstm_out2)
        
        # Lấy output timestep cuối cùng
        last_time_step = lstm_out2[:, -1, :]  # (batch_size, hidden_dim2 * 2)
        
        fc1_out = F.relu(self.fc1(last_time_step))
        fc1_out = self.dropout3(fc1_out)
        
        # out = torch.sigmoid(self.out(fc1_out))
        out = self.out(fc1_out)
        return out

# %% [markdown]
# # 3. Training Modules

# %%
# from scr.deep_learning.model.BasicLSTM import BasicLSTM
# from scr.deep_learning.model.NeuronNetwork import MLPModel
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))
import torch
from torch import nn, optim
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch.utils.data import Dataset, DataLoader

import torch
import torch.nn as nn
import torch.nn.functional as F

class DatasetLoader(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32).unsqueeze(1)  # (N, 1)
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]
    
def make_dataloader(X_train, y_train, X_dev, y_dev, X_test, y_test, batch_size=32):
    train_ds = DatasetLoader(X_train, y_train)
    dev_ds = DatasetLoader(X_dev, y_dev)
    test_ds = DatasetLoader(X_test, y_test)
    
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    dev_loader = DataLoader(dev_ds, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False)
    
    return train_loader, dev_loader, test_loader
    
# Settings
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
EPOCHS = 200
BATCH_SIZE = 256
LR = 0.0001

# Model
def _make_model(model: str, y_train: torch.Tensor, input_size: int, lr: float):   #
    if model == "BiLSTM":
        model = BiLSTMModel(input_size=input_size).to(device)
    else:
        raise ValueError("Model name không hợp lệ. Chỉ chấp nhận 'BiLSTM'.")
    pos = (y_train == 1).sum()
    neg = (y_train == 0).sum()
    pos_weight = torch.tensor(neg / pos, dtype=torch.float32).to(device)
    loss_fn = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
    optimizer = optim.Adam(
        model.parameters(),
        lr=LR
    )
    return model, loss_fn, optimizer

# Train Function
def train_model(model, loss_fn, optimizer, loader):
    model.train()
    total_loss = 0.0
    
    for X_batch, y_batch in loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        
        # 1. Reset gradient
        optimizer.zero_grad()
        
        # 2. Forward pass
        y_pred = model(X_batch)
        
        # 3. Tính loss (BCELoss expects y_pred, y in same shape)
        loss = loss_fn(y_pred, y_batch)
        
        # 4. Backward pass
        loss.backward()
        
        # 5. Update weights
        optimizer.step()
        
        # 6. Ghi nhận loss
        total_loss += loss.item()
    
    # Trung bình loss trên toàn bộ batch
    return total_loss / len(loader)

# Evaluate Function
def evaluate_model(model, loader):
    model.eval()
    y_true, y_pred = [], []
    
    with torch.no_grad():
        for X, y in loader:
            X, y = X.to(device), y.to(device)
            logits = model(X)
            probs = torch.sigmoid(logits)
            preds_class = (probs > 0.5).float()
            y_true.extend(y.cpu().numpy())
            y_pred.extend(preds_class.cpu().numpy())
            
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    
    return acc, prec, rec, f1

def training_loop(
    epochs, model, model_name, loss_fn,
    optimizer, train_loader, test_loader,
    patience=15, metric='f1'  # patience: số epoch chờ trước khi dừng; metric để theo dõi
):
    best_metric = 0
    epochs_no_improve = 0
    best_model_wts = None

    for epoch in range(epochs):
        train_loss = train_model(
            model=model, 
            loss_fn=loss_fn,
            optimizer=optimizer,
            loader=train_loader
        )
        acc, prec, rec, f1 = evaluate_model(model=model, loader=test_loader)
        
        # Lấy metric theo yêu cầu
        current_metric = None
        if metric == 'accuracy':
            current_metric = acc
        elif metric == 'precision':
            current_metric = prec
        elif metric == 'recall':
            current_metric = rec
        elif metric == 'f1':
            current_metric = f1
        else:
            raise ValueError(f"Metric {metric} không hợp lệ.")

        print(f"Epoch [{epoch+1}/{epochs}]")
        print(f"Train Loss: {train_loss:.4f}")
        print(f"Accuracy: {acc:.4f} | Precision: {prec:.4f} | Recall: {rec:.4f} | F1-score: {f1:.4f}")
        print("-" * 50)

        # Kiểm tra cải thiện
        if current_metric > best_metric:
            best_metric = current_metric
            epochs_no_improve = 0
            best_model_wts = model.state_dict()
            print(f"Model cải thiện {metric} lên {best_metric:.4f}, lưu model.")
        else:
            epochs_no_improve += 1
            print(f"Không cải thiện {metric} trong {epochs_no_improve} epoch.")

        # Nếu vượt quá patience thì dừng training sớm
        if epochs_no_improve >= patience:
            print(f"Early stopping sau {patience} epoch không cải thiện {metric}.")
            break

    # Load lại weights tốt nhất
    if best_model_wts is not None:
        model.load_state_dict(best_model_wts)
        torch.save(model.state_dict(), f"{model_name}_best.pth")
        print(f"Model tốt nhất đã được lưu tại {model_name}_best.pth")
    else:
        # Trường hợp không có cải thiện nào
        torch.save(model.state_dict(), f"{model_name}.pth")
        print(f"Không có cải thiện, model hiện tại được lưu tại {model_name}.pth")

# %% [markdown]
# # 4. Evaluating Modules

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_auc_score, average_precision_score,
    brier_score_loss, RocCurveDisplay, PrecisionRecallDisplay
)
import seaborn as sns
def predict(model, loader, device):
    """Dự đoán tập test trên data loader"""
    model.eval()
    all_preds, all_probs, all_labels = [], [], []
    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch = X_batch.to(device)
            logits = model(X_batch)
            probs = torch.sigmoid(logits)
            preds = (probs > 0.5).float()

            all_probs.extend(probs.cpu().numpy().flatten())
            all_preds.extend(preds.cpu().numpy().flatten())
            all_labels.extend(y_batch.cpu().numpy().flatten())

    return np.array(all_labels), np.array(all_preds), np.array(all_probs)

def evaluate_classification(y_true, y_pred, y_prob):
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred)
    rec = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    roc_auc = roc_auc_score(y_true, y_prob)
    pr_auc = average_precision_score(y_true, y_prob)
    brier = brier_score_loss(y_true, y_prob)

    print("Evaluation Results")
    print("-------------------------------")
    print(f"Accuracy:     {acc:.4f}")
    print(f"Precision:    {prec:.4f}")
    print(f"Recall:       {rec:.4f}")
    print(f"F1-score:     {f1:.4f}")
    print(f"ROC AUC:      {roc_auc:.4f}")
    print(f"PR AUC:       {pr_auc:.4f}")
    print(f"Brier Score:  {brier:.4f}")

    return {
        "accuracy": acc,
        "precision": prec,
        "recall": rec,
        "f1": f1,
        "roc_auc": roc_auc,
        "pr_auc": pr_auc,
        "brier": brier
    }

def plot_evaluation_curves(y_true, y_prob):
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    # 1. ROC curve
    RocCurveDisplay.from_predictions(y_true, y_prob, ax=axes[0], name="BiLSTM")
    axes[0].set_title("ROC Curve")

    # 2. Precision-Recall curve
    PrecisionRecallDisplay.from_predictions(y_true, y_prob, ax=axes[1], name="BiLSTM")
    axes[1].set_title("Precision–Recall Curve")

    # 3. Confusion Matrix
    y_pred = (np.array(y_prob) > 0.5).astype(int)
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[2])
    axes[2].set_title("Confusion Matrix")
    axes[2].set_xlabel("Predicted")
    axes[2].set_ylabel("Actual")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 5. Experiences

# %% [markdown]
# ## Model 1.
#
# + Hidden size 1: 128
#
# + Hidden size 2: 64
#
# + Learning rate: 0.0001

# %%
train_loader, dev_loader, test_loader = make_dataloader(
    X_train, y_train,
    X_dev, y_dev,
    X_test, y_test,
    batch_size=256
)

model, loss_fn, optimizer = _make_model("BiLSTM", y_train=y_train, input_size=X_train.shape[2], lr=0.0001)

training_loop(
    epochs=EPOCHS,
    model=model,
    model_name="BiLSTM1",
    loss_fn=loss_fn,
    optimizer=optimizer,
    train_loader=train_loader,
    test_loader=dev_loader
)
# Out:
# Epoch [1/200]
# Train Loss: 0.7869
# Accuracy: 0.6553 | Precision: 0.5389 | Recall: 0.6258 | F1-score: 0.5791
# --------------------------------------------------
# Model cải thiện f1 lên 0.5791, lưu model.
# Epoch [2/200]
# Train Loss: 0.7815
# Accuracy: 0.6639 | Precision: 0.5516 | Recall: 0.6047 | F1-score: 0.5769
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [3/200]
# Train Loss: 0.7789
# Accuracy: 0.6638 | Precision: 0.5504 | Recall: 0.6163 | F1-score: 0.5815
# --------------------------------------------------
# Model cải thiện f1 lên 0.5815, lưu model.
# Epoch [4/200]
# Train Loss: 0.7767
# Accuracy: 0.6638 | Precision: 0.5497 | Recall: 0.6254 | F1-score: 0.5851
# --------------------------------------------------
# Model cải thiện f1 lên 0.5851, lưu model.
# Epoch [5/200]
# Train Loss: 0.7752
# Accuracy: 0.6666 | Precision: 0.5538 | Recall: 0.6191 | F1-score: 0.5846
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [6/200]
# Train Loss: 0.7740
# Accuracy: 0.6684 | Precision: 0.5566 | Recall: 0.6145 | F1-score: 0.5841
# --------------------------------------------------
# Không cải thiện f1 trong 2 epoch.
# Epoch [7/200]
# Train Loss: 0.7730
# Accuracy: 0.6662 | Precision: 0.5524 | Recall: 0.6287 | F1-score: 0.5881
# --------------------------------------------------
# Model cải thiện f1 lên 0.5881, lưu model.
# Epoch [8/200]
# Train Loss: 0.7722
# Accuracy: 0.6726 | Precision: 0.5633 | Recall: 0.6060 | F1-score: 0.5839
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [9/200]
# Train Loss: 0.7713
# Accuracy: 0.6712 | Precision: 0.5602 | Recall: 0.6160 | F1-score: 0.5868
# --------------------------------------------------
# Không cải thiện f1 trong 2 epoch.
# Epoch [10/200]
# Train Loss: 0.7706
# Accuracy: 0.6713 | Precision: 0.5601 | Recall: 0.6183 | F1-score: 0.5878
# --------------------------------------------------
# Không cải thiện f1 trong 3 epoch.
# Epoch [11/200]
# Train Loss: 0.7699
# Accuracy: 0.6713 | Precision: 0.5598 | Recall: 0.6203 | F1-score: 0.5885
# --------------------------------------------------
# Model cải thiện f1 lên 0.5885, lưu model.
# Epoch [12/200]
# Train Loss: 0.7695
# Accuracy: 0.6702 | Precision: 0.5578 | Recall: 0.6263 | F1-score: 0.5900
# --------------------------------------------------
# Model cải thiện f1 lên 0.5900, lưu model.
# Epoch [13/200]
# Train Loss: 0.7688
# Accuracy: 0.6682 | Precision: 0.5540 | Recall: 0.6391 | F1-score: 0.5935
# --------------------------------------------------
# Model cải thiện f1 lên 0.5935, lưu model.
# Epoch [14/200]
# Train Loss: 0.7684
# Accuracy: 0.6711 | Precision: 0.5592 | Recall: 0.6249 | F1-score: 0.5902
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [15/200]
# Train Loss: 0.7681
# Accuracy: 0.6715 | Precision: 0.5596 | Recall: 0.6261 | F1-score: 0.5910
# --------------------------------------------------
# Không cải thiện f1 trong 2 epoch.
# Epoch [16/200]
# Train Loss: 0.7676
# Accuracy: 0.6711 | Precision: 0.5586 | Recall: 0.6305 | F1-score: 0.5923
# --------------------------------------------------
# Không cải thiện f1 trong 3 epoch.
# Epoch [17/200]
# Train Loss: 0.7673
# Accuracy: 0.6711 | Precision: 0.5585 | Recall: 0.6315 | F1-score: 0.5928
# --------------------------------------------------
# Không cải thiện f1 trong 4 epoch.
# Epoch [18/200]
# Train Loss: 0.7671
# Accuracy: 0.6725 | Precision: 0.5606 | Recall: 0.6283 | F1-score: 0.5925
# --------------------------------------------------
# Không cải thiện f1 trong 5 epoch.
# Epoch [19/200]
# Train Loss: 0.7667
# Accuracy: 0.6704 | Precision: 0.5571 | Recall: 0.6355 | F1-score: 0.5937
# --------------------------------------------------
# Model cải thiện f1 lên 0.5937, lưu model.
# Epoch [20/200]
# Train Loss: 0.7665
# Accuracy: 0.6702 | Precision: 0.5568 | Recall: 0.6366 | F1-score: 0.5940
# --------------------------------------------------
# Model cải thiện f1 lên 0.5940, lưu model.
# Epoch [21/200]
# Train Loss: 0.7662
# Accuracy: 0.6770 | Precision: 0.5691 | Recall: 0.6087 | F1-score: 0.5882
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [22/200]
# Train Loss: 0.7660
# Accuracy: 0.6745 | Precision: 0.5643 | Recall: 0.6198 | F1-score: 0.5908
# --------------------------------------------------
# Không cải thiện f1 trong 2 epoch.
# Epoch [23/200]
# Train Loss: 0.7656
# Accuracy: 0.6759 | Precision: 0.5666 | Recall: 0.6163 | F1-score: 0.5904
# --------------------------------------------------
# Không cải thiện f1 trong 3 epoch.
# Epoch [24/200]
# Train Loss: 0.7653
# Accuracy: 0.6742 | Precision: 0.5634 | Recall: 0.6238 | F1-score: 0.5921
# --------------------------------------------------
# Không cải thiện f1 trong 4 epoch.
# Epoch [25/200]
# Train Loss: 0.7651
# Accuracy: 0.6749 | Precision: 0.5646 | Recall: 0.6205 | F1-score: 0.5913
# --------------------------------------------------
# Không cải thiện f1 trong 5 epoch.
# Epoch [26/200]
# Train Loss: 0.7649
# Accuracy: 0.6723 | Precision: 0.5599 | Recall: 0.6320 | F1-score: 0.5938
# --------------------------------------------------
# Không cải thiện f1 trong 6 epoch.
# Epoch [27/200]
# Train Loss: 0.7647
# Accuracy: 0.6763 | Precision: 0.5670 | Recall: 0.6171 | F1-score: 0.5910
# --------------------------------------------------
# Không cải thiện f1 trong 7 epoch.
# Epoch [28/200]
# Train Loss: 0.7647
# Accuracy: 0.6727 | Precision: 0.5604 | Recall: 0.6330 | F1-score: 0.5945
# --------------------------------------------------
# Model cải thiện f1 lên 0.5945, lưu model.
# Epoch [29/200]
# Train Loss: 0.7644
# Accuracy: 0.6733 | Precision: 0.5616 | Recall: 0.6289 | F1-score: 0.5934
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [30/200]
# Train Loss: 0.7640
# Accuracy: 0.6755 | Precision: 0.5655 | Recall: 0.6207 | F1-score: 0.5918
# --------------------------------------------------
# Không cải thiện f1 trong 2 epoch.
# Epoch [31/200]
# Train Loss: 0.7640
# Accuracy: 0.6736 | Precision: 0.5620 | Recall: 0.6299 | F1-score: 0.5940
# --------------------------------------------------
# Không cải thiện f1 trong 3 epoch.
# Epoch [32/200]
# Train Loss: 0.7639
# Accuracy: 0.6770 | Precision: 0.5682 | Recall: 0.6162 | F1-score: 0.5912
# --------------------------------------------------
# Không cải thiện f1 trong 4 epoch.
# Epoch [33/200]
# Train Loss: 0.7638
# Accuracy: 0.6767 | Precision: 0.5676 | Recall: 0.6172 | F1-score: 0.5914
# --------------------------------------------------
# Không cải thiện f1 trong 5 epoch.
# Epoch [34/200]
# Train Loss: 0.7636
# Accuracy: 0.6738 | Precision: 0.5620 | Recall: 0.6311 | F1-score: 0.5946
# --------------------------------------------------
# Model cải thiện f1 lên 0.5946, lưu model.
# Epoch [35/200]
# Train Loss: 0.7634
# Accuracy: 0.6730 | Precision: 0.5605 | Recall: 0.6348 | F1-score: 0.5954
# --------------------------------------------------
# Model cải thiện f1 lên 0.5954, lưu model.
# Epoch [36/200]
# Train Loss: 0.7634
# Accuracy: 0.6754 | Precision: 0.5648 | Recall: 0.6255 | F1-score: 0.5936
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [37/200]
# Train Loss: 0.7632
# Accuracy: 0.6739 | Precision: 0.5623 | Recall: 0.6302 | F1-score: 0.5943
# --------------------------------------------------
# Không cải thiện f1 trong 2 epoch.
# Epoch [38/200]
# Train Loss: 0.7631
# Accuracy: 0.6763 | Precision: 0.5665 | Recall: 0.6210 | F1-score: 0.5925
# --------------------------------------------------
# Không cải thiện f1 trong 3 epoch.
# Epoch [39/200]
# Train Loss: 0.7630
# Accuracy: 0.6761 | Precision: 0.5661 | Recall: 0.6224 | F1-score: 0.5929
# --------------------------------------------------
# Không cải thiện f1 trong 4 epoch.
# Epoch [40/200]
# Train Loss: 0.7629
# Accuracy: 0.6785 | Precision: 0.5709 | Recall: 0.6112 | F1-score: 0.5904
# --------------------------------------------------
# Không cải thiện f1 trong 5 epoch.
# Epoch [41/200]
# Train Loss: 0.7627
# Accuracy: 0.6780 | Precision: 0.5698 | Recall: 0.6144 | F1-score: 0.5912
# --------------------------------------------------
# Không cải thiện f1 trong 6 epoch.
# Epoch [42/200]
# Train Loss: 0.7625
# Accuracy: 0.6762 | Precision: 0.5662 | Recall: 0.6230 | F1-score: 0.5932
# --------------------------------------------------
# Không cải thiện f1 trong 7 epoch.
# Epoch [43/200]
# Train Loss: 0.7625
# Accuracy: 0.6751 | Precision: 0.5642 | Recall: 0.6273 | F1-score: 0.5941
# --------------------------------------------------
# Không cải thiện f1 trong 8 epoch.
# Epoch [44/200]
# Train Loss: 0.7625
# Accuracy: 0.6746 | Precision: 0.5633 | Recall: 0.6297 | F1-score: 0.5947
# --------------------------------------------------
# Không cải thiện f1 trong 9 epoch.
# Epoch [45/200]
# Train Loss: 0.7623
# Accuracy: 0.6741 | Precision: 0.5625 | Recall: 0.6307 | F1-score: 0.5946
# --------------------------------------------------
# Không cải thiện f1 trong 10 epoch.
# Epoch [46/200]
# Train Loss: 0.7621
# Accuracy: 0.6752 | Precision: 0.5643 | Recall: 0.6275 | F1-score: 0.5942
# --------------------------------------------------
# Không cải thiện f1 trong 11 epoch.
# Epoch [47/200]
# Train Loss: 0.7621
# Accuracy: 0.6740 | Precision: 0.5620 | Recall: 0.6339 | F1-score: 0.5958
# --------------------------------------------------
# Model cải thiện f1 lên 0.5958, lưu model.
# Epoch [48/200]
# Train Loss: 0.7621
# Accuracy: 0.6748 | Precision: 0.5634 | Recall: 0.6309 | F1-score: 0.5953
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [49/200]
# Train Loss: 0.7619
# Accuracy: 0.6760 | Precision: 0.5657 | Recall: 0.6252 | F1-score: 0.5940
# --------------------------------------------------
# Không cải thiện f1 trong 2 epoch.
# Epoch [50/200]
# Train Loss: 0.7619
# Accuracy: 0.6776 | Precision: 0.5687 | Recall: 0.6182 | F1-score: 0.5924
# --------------------------------------------------
# Không cải thiện f1 trong 3 epoch.
# Epoch [51/200]
# Train Loss: 0.7616
# Accuracy: 0.6783 | Precision: 0.5700 | Recall: 0.6150 | F1-score: 0.5917
# --------------------------------------------------
# Không cải thiện f1 trong 4 epoch.
# Epoch [52/200]
# Train Loss: 0.7617
# Accuracy: 0.6757 | Precision: 0.5650 | Recall: 0.6273 | F1-score: 0.5945
# --------------------------------------------------
# Không cải thiện f1 trong 5 epoch.
# Epoch [53/200]
# Train Loss: 0.7616
# Accuracy: 0.6766 | Precision: 0.5666 | Recall: 0.6238 | F1-score: 0.5938
# --------------------------------------------------
# Không cải thiện f1 trong 6 epoch.
# Epoch [54/200]
# Train Loss: 0.7613
# Accuracy: 0.6776 | Precision: 0.5686 | Recall: 0.6194 | F1-score: 0.5929
# --------------------------------------------------
# Không cải thiện f1 trong 7 epoch.
# Epoch [55/200]
# Train Loss: 0.7613
# Accuracy: 0.6759 | Precision: 0.5652 | Recall: 0.6283 | F1-score: 0.5951
# --------------------------------------------------
# Không cải thiện f1 trong 8 epoch.
# Epoch [56/200]
# Train Loss: 0.7612
# Accuracy: 0.6753 | Precision: 0.5642 | Recall: 0.6295 | F1-score: 0.5951
# --------------------------------------------------
# Không cải thiện f1 trong 9 epoch.
# Epoch [57/200]
# Train Loss: 0.7612
# Accuracy: 0.6781 | Precision: 0.5696 | Recall: 0.6167 | F1-score: 0.5922
# --------------------------------------------------
# Không cải thiện f1 trong 10 epoch.
# Epoch [58/200]
# Train Loss: 0.7612
# Accuracy: 0.6753 | Precision: 0.5641 | Recall: 0.6298 | F1-score: 0.5952
# --------------------------------------------------
# Không cải thiện f1 trong 11 epoch.
# Epoch [59/200]
# Train Loss: 0.7612
# Accuracy: 0.6756 | Precision: 0.5646 | Recall: 0.6292 | F1-score: 0.5952
# --------------------------------------------------
# Không cải thiện f1 trong 12 epoch.
# Epoch [60/200]
# Train Loss: 0.7611
# Accuracy: 0.6744 | Precision: 0.5623 | Recall: 0.6354 | F1-score: 0.5966
# --------------------------------------------------
# Model cải thiện f1 lên 0.5966, lưu model.
# Epoch [61/200]
# Train Loss: 0.7612
# Accuracy: 0.6777 | Precision: 0.5686 | Recall: 0.6200 | F1-score: 0.5932
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [62/200]
# Train Loss: 0.7611
# Accuracy: 0.6741 | Precision: 0.5619 | Recall: 0.6362 | F1-score: 0.5967
# --------------------------------------------------
# Model cải thiện f1 lên 0.5967, lưu model.
# Epoch [63/200]
# Train Loss: 0.7608
# Accuracy: 0.6735 | Precision: 0.5609 | Recall: 0.6382 | F1-score: 0.5970
# --------------------------------------------------
# Model cải thiện f1 lên 0.5970, lưu model.
# Epoch [64/200]
# Train Loss: 0.7608
# Accuracy: 0.6765 | Precision: 0.5660 | Recall: 0.6274 | F1-score: 0.5951
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [65/200]
# Train Loss: 0.7606
# Accuracy: 0.6740 | Precision: 0.5617 | Recall: 0.6361 | F1-score: 0.5966
# --------------------------------------------------
# Không cải thiện f1 trong 2 epoch.
# Epoch [66/200]
# Train Loss: 0.7607
# Accuracy: 0.6752 | Precision: 0.5640 | Recall: 0.6306 | F1-score: 0.5954
# --------------------------------------------------
# Không cải thiện f1 trong 3 epoch.
# Epoch [67/200]
# Train Loss: 0.7606
# Accuracy: 0.6792 | Precision: 0.5714 | Recall: 0.6143 | F1-score: 0.5921
# --------------------------------------------------
# Không cải thiện f1 trong 4 epoch.

# %% [markdown]
# ## Model 2
#
# + Hidden size 1: 64
#
# + Hidden size 2: 32
#
# + Learning rate: 0.0001

# %% [markdown]
# ### a. Training

# %%
train_loader, dev_loader, test_loader = make_dataloader(
    X_train, y_train,
    X_dev, y_dev,
    X_test, y_test,
    batch_size=256
)

model2, loss_fn, optimizer = _make_model("BiLSTM", y_train=y_train, input_size=X_train.shape[2], lr=LR)

training_loop(
    epochs=EPOCHS,
    model=model2,
    model_name="BiLSTM",
    loss_fn=loss_fn,
    optimizer=optimizer,
    train_loader=train_loader,
    test_loader=dev_loader
)
# Out:
# Epoch [1/200]
# Train Loss: 0.7888
# Accuracy: 0.6615 | Precision: 0.5485 | Recall: 0.6043 | F1-score: 0.5751
# --------------------------------------------------
# Model cải thiện f1 lên 0.5751, lưu model.
# Epoch [2/200]
# Train Loss: 0.7846
# Accuracy: 0.6699 | Precision: 0.5628 | Recall: 0.5780 | F1-score: 0.5703
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [3/200]
# Train Loss: 0.7826
# Accuracy: 0.6620 | Precision: 0.5481 | Recall: 0.6166 | F1-score: 0.5803
# --------------------------------------------------
# Model cải thiện f1 lên 0.5803, lưu model.
# Epoch [4/200]
# Train Loss: 0.7815
# Accuracy: 0.6648 | Precision: 0.5521 | Recall: 0.6123 | F1-score: 0.5806
# --------------------------------------------------
# Model cải thiện f1 lên 0.5806, lưu model.
# Epoch [5/200]
# Train Loss: 0.7810
# Accuracy: 0.6710 | Precision: 0.5635 | Recall: 0.5852 | F1-score: 0.5741
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [6/200]
# Train Loss: 0.7803
# Accuracy: 0.6606 | Precision: 0.5450 | Recall: 0.6333 | F1-score: 0.5859
# --------------------------------------------------
# Model cải thiện f1 lên 0.5859, lưu model.
# Epoch [7/200]
# Train Loss: 0.7799
# Accuracy: 0.6663 | Precision: 0.5543 | Recall: 0.6107 | F1-score: 0.5812
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [8/200]
# Train Loss: 0.7793
# Accuracy: 0.6723 | Precision: 0.5654 | Recall: 0.5853 | F1-score: 0.5752
# --------------------------------------------------
# Không cải thiện f1 trong 2 epoch.
# Epoch [9/200]
# Train Loss: 0.7790
# Accuracy: 0.6706 | Precision: 0.5619 | Recall: 0.5941 | F1-score: 0.5776
# --------------------------------------------------
# Không cải thiện f1 trong 3 epoch.
# Epoch [10/200]
# Train Loss: 0.7789
# Accuracy: 0.6641 | Precision: 0.5499 | Recall: 0.6265 | F1-score: 0.5857
# --------------------------------------------------
# Không cải thiện f1 trong 4 epoch.
# Epoch [11/200]
# Train Loss: 0.7785
# Accuracy: 0.6691 | Precision: 0.5587 | Recall: 0.6037 | F1-score: 0.5803
# --------------------------------------------------
# Không cải thiện f1 trong 5 epoch.
# Epoch [12/200]
# Train Loss: 0.7783
# Accuracy: 0.6721 | Precision: 0.5643 | Recall: 0.5914 | F1-score: 0.5775
# --------------------------------------------------
# Không cải thiện f1 trong 6 epoch.
# Epoch [13/200]
# Train Loss: 0.7780
# Accuracy: 0.6723 | Precision: 0.5646 | Recall: 0.5921 | F1-score: 0.5780
# --------------------------------------------------
# Không cải thiện f1 trong 7 epoch.
# Epoch [14/200]
# Train Loss: 0.7778
# Accuracy: 0.6681 | Precision: 0.5566 | Recall: 0.6112 | F1-score: 0.5826
# --------------------------------------------------
# Không cải thiện f1 trong 8 epoch.
# Epoch [15/200]
# Train Loss: 0.7776
# Accuracy: 0.6731 | Precision: 0.5661 | Recall: 0.5892 | F1-score: 0.5774
# --------------------------------------------------
# Không cải thiện f1 trong 9 epoch.
# Epoch [16/200]
# Train Loss: 0.7775
# Accuracy: 0.6697 | Precision: 0.5593 | Recall: 0.6050 | F1-score: 0.5813
# --------------------------------------------------
# Không cải thiện f1 trong 10 epoch.
# Epoch [17/200]
# Train Loss: 0.7775
# Accuracy: 0.6696 | Precision: 0.5591 | Recall: 0.6061 | F1-score: 0.5817
# --------------------------------------------------
# Không cải thiện f1 trong 11 epoch.
# Epoch [18/200]
# Train Loss: 0.7772
# Accuracy: 0.6715 | Precision: 0.5627 | Recall: 0.5980 | F1-score: 0.5798
# --------------------------------------------------
# Không cải thiện f1 trong 12 epoch.
# Epoch [19/200]
# Train Loss: 0.7770
# Accuracy: 0.6713 | Precision: 0.5620 | Recall: 0.6015 | F1-score: 0.5811
# --------------------------------------------------
# Không cải thiện f1 trong 13 epoch.
# Epoch [20/200]
# Train Loss: 0.7769
# Accuracy: 0.6633 | Precision: 0.5482 | Recall: 0.6343 | F1-score: 0.5881
# --------------------------------------------------
# Model cải thiện f1 lên 0.5881, lưu model.
# Epoch [21/200]
# Train Loss: 0.7771
# Accuracy: 0.6708 | Precision: 0.5608 | Recall: 0.6061 | F1-score: 0.5826
# --------------------------------------------------
# Không cải thiện f1 trong 1 epoch.
# Epoch [22/200]
# Train Loss: 0.7768
# Accuracy: 0.6638 | Precision: 0.5490 | Recall: 0.6328 | F1-score: 0.5879
# --------------------------------------------------
# Không cải thiện f1 trong 2 epoch.
# Epoch [23/200]
# Train Loss: 0.7767
# Accuracy: 0.6674 | Precision: 0.5550 | Recall: 0.6169 | F1-score: 0.5843
# --------------------------------------------------
# Không cải thiện f1 trong 3 epoch.
# Epoch [24/200]
# Train Loss: 0.7766
# Accuracy: 0.6673 | Precision: 0.5548 | Recall: 0.6186 | F1-score: 0.5850
# --------------------------------------------------
# Không cải thiện f1 trong 4 epoch.
# Epoch [25/200]
# Train Loss: 0.7766
# Accuracy: 0.6705 | Precision: 0.5604 | Recall: 0.6061 | F1-score: 0.5823
# --------------------------------------------------
# Không cải thiện f1 trong 5 epoch.
# Epoch [26/200]
# Train Loss: 0.7763
# Accuracy: 0.6713 | Precision: 0.5619 | Recall: 0.6020 | F1-score: 0.5813
# --------------------------------------------------
# Không cải thiện f1 trong 6 epoch.
# Epoch [27/200]
# Train Loss: 0.7762
# Accuracy: 0.6688 | Precision: 0.5571 | Recall: 0.6148 | F1-score: 0.5846
# --------------------------------------------------
# Không cải thiện f1 trong 7 epoch.
# Epoch [28/200]
# Train Loss: 0.7764
# Accuracy: 0.6712 | Precision: 0.5616 | Recall: 0.6038 | F1-score: 0.5819
# --------------------------------------------------
# Không cải thiện f1 trong 8 epoch.
# Epoch [29/200]
# Train Loss: 0.7761
# Accuracy: 0.6690 | Precision: 0.5576 | Recall: 0.6131 | F1-score: 0.5840
# --------------------------------------------------
# Không cải thiện f1 trong 9 epoch.
# Epoch [30/200]
# Train Loss: 0.7761
# Accuracy: 0.6668 | Precision: 0.5538 | Recall: 0.6221 | F1-score: 0.5859
# --------------------------------------------------
# Không cải thiện f1 trong 10 epoch.
# Epoch [31/200]
# Train Loss: 0.7762
# Accuracy: 0.6747 | Precision: 0.5687 | Recall: 0.5857 | F1-score: 0.5771
# --------------------------------------------------
# Không cải thiện f1 trong 11 epoch.
# Epoch [32/200]
# Train Loss: 0.7758
# Accuracy: 0.6700 | Precision: 0.5595 | Recall: 0.6081 | F1-score: 0.5828
# --------------------------------------------------
# Không cải thiện f1 trong 12 epoch.
# Epoch [33/200]
# Train Loss: 0.7760
# Accuracy: 0.6720 | Precision: 0.5632 | Recall: 0.6000 | F1-score: 0.5810
# --------------------------------------------------
# Không cải thiện f1 trong 13 epoch.
# Epoch [34/200]
# Train Loss: 0.7761
# Accuracy: 0.6687 | Precision: 0.5573 | Recall: 0.6120 | F1-score: 0.5834
# --------------------------------------------------
# Không cải thiện f1 trong 14 epoch.
# Epoch [35/200]
# Train Loss: 0.7759
# Accuracy: 0.6687 | Precision: 0.5568 | Recall: 0.6164 | F1-score: 0.5851
# --------------------------------------------------
# Không cải thiện f1 trong 15 epoch.
# Early stopping sau 15 epoch không cải thiện f1.
# Model tốt nhất đã được lưu tại BiLSTM_best.pth

# %% [markdown]
# ### b. Evaluating

# %%
y_true, y_pred, y_prob = predict(model2, test_loader, device)
metrics = evaluate_classification(y_true, y_pred, y_prob)
plot_evaluation_curves(y_true, y_prob)
# Out:
# Evaluation Results
# -------------------------------
# Accuracy:     0.6693
# Precision:    0.5576
# Recall:       0.6171
# F1-score:     0.5859
# ROC AUC:      0.7170
# PR AUC:       0.6154
# Brier Score:  0.2132
